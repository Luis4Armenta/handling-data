# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/luigi/data_science/db/base_datos_2008.csv", nrows= 100000)

# %%
df.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
# 1  2008      1           3          4    754.0         735   1002.0
# 2  2008      1           3          4    628.0         620    804.0
# 3  2008      1           3          4    926.0         930   1054.0
# 4  2008      1           3          4   1829.0        1755   1959.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        2225            WN        335  ...    4.0      8.0          0
# 1        1000            WN       3231  ...    5.0     10.0          0
# 2         750            WN        448  ...    3.0     17.0          0
# 3        1100            WN       1746  ...    3.0      7.0          0
# 4        1925            WN       3920  ...    3.0     10.0          0
#
#    CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
df.tail()
# Out:
#        Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 99995  2008      1          25          5   2204.0        1935    106.0
# 99996  2008      1          26          6   1933.0        1935   2234.0
# 99997  2008      1          27          7   2047.0        1935   2400.0
# 99998  2008      1          28          1   1956.0        1935   2308.0
# 99999  2008      1          29          2   1938.0        1935   2308.0
#
#        CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 99995        2257            XE       7676  ...    4.0     17.0          0
# 99996        2257            XE       7676  ...    4.0     16.0          0
# 99997        2257            XE       7676  ...    6.0     18.0          0
# 99998        2257            XE       7676  ...    5.0     25.0          0
# 99999        2257            XE       7676  ...    5.0     41.0          0
#
#        CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
df = df.sample(frac = 1) # Desordenar filas

# %%
df.columns # Obtener columnas
# Out:
# Index(['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime',
#        'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum', 'TailNum',
#        'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],
#       dtype='object')

# %%
df.DepTime
# Out:
# 92605    1802.0
# 49773    1140.0
# 22006    1142.0
# 45210       NaN
# 47199    1316.0
#           ...
# 47326    2052.0
# 34658     754.0
# 15981    1934.0
# 7542      756.0
# 5815     1840.0
# Name: DepTime, Length: 100000, dtype: float64

# %%
df.dtypes # Muestra tipos de variables
# Out:
# Year                   int64
# Month                  int64
# DayofMonth             int64
# DayOfWeek              int64
# DepTime              float64
# CRSDepTime             int64
# ArrTime              float64
# CRSArrTime             int64
# UniqueCarrier         object
# FlightNum              int64
# TailNum               object
# ActualElapsedTime    float64
# CRSElapsedTime         int64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Origin                object
# Dest                  object
# Distance               int64
# TaxiIn               float64
# TaxiOut              float64
# Cancelled              int64
# CancellationCode      object
# Diverted               int64
# CarrierDelay         float64
# WeatherDelay         float64
# NASDelay             float64
# SecurityDelay        float64
# LateAircraftDelay    float64
# dtype: object

# %%
df.values # obtener datos en un array
# Out:
# array([[2008, 1, 31, ..., 4.0, 0.0, 22.0],
#        [2008, 1, 18, ..., 3.0, 0.0, 57.0],
#        [2008, 1, 9, ..., nan, nan, nan],
#        ...,
#        [2008, 1, 8, ..., nan, nan, nan],
#        [2008, 1, 5, ..., nan, nan, nan],
#        [2008, 1, 5, ..., 0.0, 0.0, 95.0]], dtype=object)

# %%
df2 = df.head(10) # Crear un nuevo DataFrame en memoria

# %%
df2.head(20) # Obtener las primeras 20 filas.
# Out:
#        Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 92605  2008      1          31          4   1802.0        1740   2121.0
# 49773  2008      1          18          5   1140.0        1040   1243.0
# 22006  2008      1           9          3   1142.0        1140   1311.0
# 45210  2008      1          17          4      NaN         710      NaN
# 47199  2008      1          17          4   1316.0        1315   1424.0
# 38164  2008      1          14          1   1354.0        1355   1500.0
# 64612  2008      1          23          3   2142.0        2000   2244.0
# 99056  2008      1          11          5    921.0         925   1119.0
# 19321  2008      1           9          3   1702.0        1705   1807.0
# 41249  2008      1          15          2   1425.0        1415   1619.0
#
#        CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 92605        2055            WN       2532  ...    6.0     18.0          0
# ...
